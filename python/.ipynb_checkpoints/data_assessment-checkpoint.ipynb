# %%
# @BEGIN data_assessement @desc Assess quality of dataset
# @in farmersmarket
# @out report @desc Assessement report

# %%
import pandas as pd
dataset = pd.read_csv('farmersmarkets.csv')

# %%
# @begin table_assessment @des Assess length, uniqueness, null values, types
print('N of row:',len(dataset),'; N of columns',len(dataset.columns))
# Out:
# N of row: 8687 ; N of columns 59

# %%
types = pd.DataFrame(data=dataset.dtypes)
types['name']= list(types.index)
types = types.rename(index=str, columns={0: "object"})

# %%
types
# Out:
#                 object           name
# FMID             int64           FMID
# MarketName      object     MarketName
# Website         object        Website
# Facebook        object       Facebook
# Twitter         object        Twitter
# Youtube         object        Youtube
# OtherMedia      object     OtherMedia
# street          object         street
# city            object           city
# County          object         County
# State           object          State
# zip             object            zip
# Season1Date     object    Season1Date
# Season1Time     object    Season1Time
# Season2Date     object    Season2Date
# Season2Time     object    Season2Time
# Season3Date     object    Season3Date
# Season3Time     object    Season3Time
# Season4Date     object    Season4Date
# Season4Time     object    Season4Time
# x              float64              x
# y              float64              y
# Location        object       Location
# Credit          object         Credit
# ...

# %%
types.groupby(['object'])['name'].count()
# Out:
# object
# int64       1
# float64     2
# object     56
# Name: name, dtype: int64

# %%
dataset.isnull().sum()
# Out:
# FMID                0
# MarketName          0
# Website          3475
# Facebook         4756
# Twitter          7672
# Youtube          8508
# OtherMedia       7962
# street            290
# city               39
# County            515
# State               0
# zip               944
# Season1Date      3208
# Season1Time      3050
# Season2Date      8238
# Season2Time      8250
# Season3Date      8606
# Season3Time      8610
# Season4Date      8681
# Season4Time      8681
# x                  29
# y                  29
# Location         5958
# Credit              0
# WIC                 0
# WICcash             0
# SFMNP               0
# SNAP                0
# Organic             0
# Bakedgoods       2933
# Cheese           2933
# Crafts           2933
# Flowers          2933
# Eggs             2933
# Seafood          2933
# Herbs            2933
# Vegetables       2933
# Honey            2933
# Jams             2933
# Maple            2933
# Meat             2933
# ...

# %%
for i in range(23, 58):
        print(dataset.iloc[:,i].unique())
# Out:
# ['Y' 'N']
# ['Y' 'N']
# ['N' 'Y']
# ['Y' 'N']
# ['N' 'Y']
# ['Y' '-' 'N']
# ['Y' nan 'N']
# ['Y' 'N' nan]
# ['Y' nan 'N']
# ['Y' nan 'N']
# ['Y' nan 'N']
# ['N' nan 'Y']
# ['Y' nan 'N']
# ['Y' nan 'N']
# ['Y' nan 'N']
# ['Y' nan 'N']
# ['Y' nan 'N']
# ['Y' 'N' nan]
# ['N' nan 'Y']
# ['N' nan 'Y']
# ['N' nan 'Y']
# ['Y' nan 'N']
# ['Y' 'N' nan]
# ['Y' nan 'N']
# ['Y' 'N' nan]
# ['N' nan 'Y']
# ['Y' 'N' nan]
# ['Y' 'N' nan]
# ['Y' nan 'N']
# ['N' nan 'Y']
# ['N' nan 'Y']
# ['Y' 'N' nan]
# ['Y' 'N' nan]
# ['N' nan 'Y']
# ['N' nan 'Y']

# %%
dataset.zip.unique()
# Out:
# array(['05828', nan, '29682', ..., '84767', '46077', '64153'],
#       dtype=object)

# %%
dataset.FMID = dataset.FMID.astype(str)

# %%
len(dataset.FMID.unique().tolist())
# Out:
# 8687

# %%
dataset.head()
# Out:
#       FMID                                        MarketName  \
# 0  1018261   Caledonia Farmers Market Association - Danville
# 1  1018318                 Stearns Homestead Farmers' Market
# 2  1009364                 106 S. Main Street Farmers Market
# 3  1010691               10th Steet Community Farmers Market
# 4  1002454                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# ...

# %%
dataset[['Season1Date','Season1Time','Season2Date','Season2Time',
'Season3Date','Season3Time','Season4Date','Season4Time','zip']].head()
# Out:
#                 Season1Date                                   Season1Time  \
# 0  06/14/2017 to 08/30/2017                         Wed: 9:00 AM-1:00 PM;
# 1  06/24/2017 to 09/30/2017                         Sat: 9:00 AM-1:00 PM;
# 2                       NaN                                           NaN
# 3  04/02/2014 to 11/30/2014    Wed: 3:00 PM-6:00 PM;Sat: 8:00 AM-1:00 PM;
# 4          July to November  Tue:8:00 am - 5:00 pm;Sat:8:00 am - 8:00 pm;
#
#                 Season2Date            Season2Time Season3Date Season3Time  \
# 0  09/06/2017 to 10/18/2017  Wed: 2:00 PM-6:00 PM;         NaN         NaN
# 1                       NaN                    NaN         NaN         NaN
# 2                       NaN                    NaN         NaN         NaN
# 3                       NaN                    NaN         NaN         NaN
# 4                       NaN                    NaN         NaN         NaN
#
#   Season4Date Season4Time    zip
# 0         NaN         NaN  05828
# ...

# %%
len(dataset.State.unique())
# Out:
# 53

# %%
dataset.County.unique()
# Out:
# array(['Caledonia', 'Cuyahoga', nan, ..., 'Yancey', 'Golden Valley',
#        'Sherburne'], dtype=object)

# %%
dataset.MarketName.head()
# Out:
# 0     Caledonia Farmers Market Association - Danville
# 1                   Stearns Homestead Farmers' Market
# 2                   106 S. Main Street Farmers Market
# 3                 10th Steet Community Farmers Market
# 4                                112st Madison Avenue
# Name: MarketName, dtype: object
